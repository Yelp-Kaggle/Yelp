# %%
from __future__ import division
import pandas as pd
import numpy as np
#import matplotlib.dates as mdates
#import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import time

train_data = pd.read_csv("D:\\Desktop\\Material\\STAT 154\\Kaggle\\ShrinkedData\\yelp_academic_dataset_business_train.csv")
test_data = pd.read_csv('D:\\Desktop\\Material\\STAT 154\\Kaggle\\ShrinkedData\\yelp_academic_dataset_business_test.csv')
train_length = train_data.shape[0]
test_length = test_data.shape[0]
print(train_length,test_length)
# Out:
# (2510, 440)

# %%
train_data.loc[[0]]
# Out:
#    Unnamed: 0 neighborhood             business_id  \
# 0          85          NaN  Ja4stXdNYr39u5CZHMNtjw
#
#                                                hours  is_open         address  \
# 0  ['Monday 11:0-23:0', 'Tuesday 11:0-0:0', 'Wedn...        1  7228 E 1st Ave
#
#                                           attributes  \
# 0  ['Alcohol: full_bar', "Ambience: {'romantic': ...
#
#                    categories        city  review_count  \
# 0  ['Mexican', 'Restaurants']  Scottsdale           480
#
#                           name   longitude state  stars   latitude  \
# 0  Cien Agaves Tacos & Tequila -111.925341    AZ    3.5  33.494399
#
#    postal_code      type
# 0        85251  business

# %%
test_data.loc[[0]]
# Out:
#    Unnamed: 0  Unnamed: 0.1 neighborhood             business_id hours  \
# 0           0           300     Eastside  CCNp1qS8n2gh51X7Wadabw   NaN
#
#    is_open           address  \
# 0        0  3000 Paradise Rd
#
#                                           attributes  \
# 0  ['Alcohol: full_bar', "Ambience: {'romantic': ...
#
#                    categories       city  review_count  \
# 0  ['Mexican', 'Restaurants']  Las Vegas            60
#
#                            name   longitude state   latitude  postal_code  \
# 0  Vince Neil's Tatuado Cantina -115.151412    NV  36.136285        89109
#
#        type
# 0  business

# %%
train_location_group = train_data.groupby(['state','city','categories']).count()

# %%
train_data.groupby(['state','city','categories']).aggregate([np.sum,np.mean,np.std])
# Out:
#                                             Unnamed: 0                \
#                                                    sum          mean
# state city       categories
# AZ    Glendale   ['Chinese', 'Restaurants']    1036084  86340.333333
#                  ['Coffee & Tea', 'Food']       785917  78591.700000
#                  ['Food', 'Coffee & Tea']       702359  78039.888889
#                  ['Mexican', 'Restaurants']    1417701  94513.400000
#                  ['Pizza', 'Restaurants']      1277190  98245.384615
#                  ['Restaurants', 'Chinese']     405873  67645.500000
#                  ['Restaurants', 'Mexican']    2016103  87656.652174
#                  ['Restaurants', 'Pizza']       881099  80099.909091
#       Phoenix    ['Chinese', 'Restaurants']    4107676  77503.320755
#                  ['Coffee & Tea', 'Food']      4268645  82089.326923
#                  ['Food', 'Coffee & Tea']      4207049  65735.140625
# ...

# %%
train_location_group['postal_code']
# Out:
# state  city        categories
# AZ     Glendale    ['Chinese', 'Restaurants']     12
#                    ['Coffee & Tea', 'Food']       10
#                    ['Food', 'Coffee & Tea']        9
#                    ['Mexican', 'Restaurants']     15
#                    ['Pizza', 'Restaurants']       13
#                    ['Restaurants', 'Chinese']      6
#                    ['Restaurants', 'Mexican']     23
#                    ['Restaurants', 'Pizza']       11
#        Phoenix     ['Chinese', 'Restaurants']     53
#                    ['Coffee & Tea', 'Food']       52
#                    ['Food', 'Coffee & Tea']       64
#                    ['Mexican', 'Restaurants']    148
#                    ['Pizza', 'Restaurants']       46
#                    ['Restaurants', 'Chinese']     33
#                    ['Restaurants', 'Mexican']    121
#                    ['Restaurants', 'Pizza']       42
#        Scottsdale  ['Chinese', 'Restaurants']      6
# ...

# %%
train_location_group
# Out:
#                                              Unnamed: 0  neighborhood  \
# state city       categories
# AZ    Glendale   ['Chinese', 'Restaurants']          12             0
#                  ['Coffee & Tea', 'Food']            10             0
#                  ['Food', 'Coffee & Tea']             9             0
#                  ['Mexican', 'Restaurants']          15             0
#                  ['Pizza', 'Restaurants']            13             0
#                  ['Restaurants', 'Chinese']           6             0
#                  ['Restaurants', 'Mexican']          23             0
#                  ['Restaurants', 'Pizza']            11             0
#       Phoenix    ['Chinese', 'Restaurants']          53             0
#                  ['Coffee & Tea', 'Food']            52             0
#                  ['Food', 'Coffee & Tea']            64             0
#                  ['Mexican', 'Restaurants']         148             0
# ...

# %%
train_location_group.aggregate(['stars']).mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-b6451528eec0> in <module>()
# ----> 1 train_location_group.aggregate(['stars']).mean()
#
# D:\Anaconda2.7\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'aggregate'

# %%
test_data.groupby(['state','city']).count()
# Out:
#                   Unnamed: 0  Unnamed: 0.1  neighborhood  business_id  hours  \
# state city
# AZ    Glendale            26            26             0           26     16
#       Phoenix             88            88             0           88     50
#       Scottsdale          21            21             0           21     17
#       Tempe               14            14             0           14      6
# NC    Charlotte           42            42            28           42     25
# NV    Henderson           20            20             2           20     15
#       Las Vegas          130           130           107          130     75
# OH    Cleveland           29            29            10           29     14
# PA    Pittsburgh          57            57            33           57     40
# WI    Madison             13            13            11           13      7
#
#                   is_open  address  attributes  categories  review_count  \
# state city
# ...

# %%
import gmaps
import gmaps.datasets
gmaps.configure(api_key="AIzaSyAk7orltB3DsnW2uL1scgWGn8K7_3PdNkI") # Your Google API key

# %%
import googlemaps
import gmaps
import gmaps.datasets

# %%
sample = train_data.loc[[0]]
sample_coor = (sample['latitude'],sample['longitude'])
locations = np.array(sample_coor)

# %%
locations
# Out:
# array([[  33.4943986],
#        [-111.9253409]])

# %%
location = gmaps.datasets.load_dataset("taxi_rides")

m = gmaps.Map()
m.add_layer(gmaps.heatmap_layer(location))
m

# %%
#m = gmaps.Map()
#m.add_layer(gmaps.heatmap_layer(locations))
#m

# %%
import gmplot

gmap = gmplot.GoogleMapPlotter(37.428, -122.145, 16)
latitudes = sample['latitude']
longitudes = sample['longitude']
gmap.plot(latitudes, longitudes, 'cornflowerblue', edge_width=10)
gmap.scatter(latitudes, longitudes, '#3B0B39', size=40, marker=False)
#gmap.scatter(marker_lats, marker_lngs, 'k', marker=True)
#gmap.heatmap(heat_lats, heat_lngs)

gmap.draw("mymap.html")

# %%
import gmaps
import gmaps.datasets
gmaps.configure(api_key="AIzaSyAk7orltB3DsnW2uL1scgWGn8K7_3PdNkI") # Your Google API key

# load a Numpy array of (latitude, longitude) pairs
locations = gmaps.datasets.load_dataset("taxi_rides")

m = gmaps.Map()
m.add_layer(gmaps.heatmap_layer(locations))
print("Done")
m
